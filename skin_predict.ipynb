# %%
#to enable file uploading follow below instruction 

# Go to chrome://settings/content/cookies
# Turn off-> Block third-party cookies

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Import different kinds of library
import numpy as np
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras import Model, layers
from keras.models import load_model, model_from_json

# %%
model2 = load_model('/content/drive/MyDrive/abc.h5')

# %%
import os
import shutil
from io import BytesIO


from google.colab import files
uploaded = files.upload()

im = Image.open(BytesIO(uploaded[list(uploaded.keys())[0]]))



import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()


testing_Image_path = list(uploaded.keys())[0]
try:
  os.mkdir("test")
except:
  pass

try:
  os.mkdir("test/c1")
except:
  pass

shutil.move(testing_Image_path,"/content/test/c1")






class_name = ['Nail_psoriasis', 'SJS-TEN', 'Vitiligo', 'acne', 'hyperpigmentation']
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_name[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence



#Load the dataset the JPES files what we converted before
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3
tester=tf.keras.preprocessing.image_dataset_from_directory(
    '//content/test',
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)



predicted = []
actual = []
for images, labels in tester:
  for i in range(1):
    predicted_class, confidence =predict(model2, images[i].numpy())
    print("Predicted_class: "+ predicted_class)

  


os.remove(os.path.join("test/c1",testing_Image_path))
# Out:
#      <input type="file" id="files-2d77c4d7-5959-485a-860d-a7da702b3ef5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d77c4d7-5959-485a-860d-a7da702b3ef5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sjs-ten-ocular-20__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDgyXQ.jpeg to sjs-ten-ocular-20__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDgyXQ.jpeg
# Found 1 files belonging to 1 classes.
# Predicted_class: SJS-TEN
